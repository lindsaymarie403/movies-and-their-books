# %% [markdown]
# Tracking the histories of books-turned-movies on the NYT Best Sellers List. What sort of relationship exists between the book's rank and the date its movie was released?
#
# Note: The list combines all books in a series into one listing under Children's Series. This is relevant for the following books/movies I'm examining: The Twilight Saga: Eclipse, Harry Potter and the Deathly Hallows Part 1, Harry Potter and the Deathly Hallows Part 2, The Twilight Saga: Breaking Dawn Part 1, The Hunger Games, The Twilight Saga Breaking Dawn Part 2, The Hunger Games: Catching Fire, The Hunger Games: Mockingjay - Part 1 and The Hunger Games: Mockingjay - Part 2.

# %%
import requests
import pandas as pd
import json

# %%
data = pd.read_csv('input/trade-fiction-it4.csv', encoding='utf8')

dates = data['Date'].tolist()

print(dates)
# Out:
# ['2017-12-17', '2017-12-24', '2017-12-31', '2018-01-07', '2018-01-14']

# %%
for date in dates:
    # Set up the parameters we want to pass to the API.
    parameters = {"api-key": "e67cf24bfe5e41628e9b424f1e479900", "list": "trade-fiction-paperback", "published-date": date}
    
    # Make a get request with the parameters.
    response = requests.get("https://api.nytimes.com/svc/books/v3/lists.json", params=parameters)
    
    response = response.json()
    
    print(response)
    
    with open('output/data4.json', 'a') as outfile:
        json.dump(response, outfile, indent=4, sort_keys=True)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 10, 'last_modified': '2017-12-08T14:38:01-05:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-02', 'published_date': '2017-12-17', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Darker-Fifty-Shades-Told-Christian-ebook/dp/B07693HRS9?tag=NYTBS-20', 'isbns': [{'isbn10': '0385543913', 'isbn13': '9780385543910'}, {'isbn10': '0385543980', 'isbn13': '9780385543989'}], 'book_details': [{'title': 'DARKER', 'description': "Christian Grey's tormented and difficult pursuit of Anastasia Steele is told from his perspective.", 'contributor': 'by E.L. James', 'author': 'EL James', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Vintage', 'primary_isbn13': '9780385543910', 'primary_isbn10': '0385543913'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-02', 'published_date': '2017-12-17', 'rank': 2, 'rank_last_week': 1, 'weeks_on_list': 9, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Sun-Her-Flowers-Rupi-Kaur/dp/1449486797?tag=NYTBS-20', 'isbns': [{'isbn10': '1449486797', 'isbn13': '9781449486792'}, {'isbn10': '1449488897', 'isbn13': '9781449488895'}], 'book_details': [{'title': 'THE SUN AND HER FLOWERS', 'description': 'A second collection of poetry from the author of "Milk and Honey."', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449486792', 'primary_isbn10': '1449486797'}], 'reviews': [{'book_review_link': 'https://www.nytimes.com/2017/12/15/books/review/rupi-kaur-instapoets.html', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-02', 'published_date': '2017-12-17', 'rank': 3, 'rank_last_week': 2, 'weeks_on_list': 86, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Milk-Honey-Rupi-Kaur/dp/144947425X?tag=NYTBS-20', 'isbns': [{'isbn10': '144947425X', 'isbn13': '9781449474256'}], 'book_details': [{'title': 'MILK AND HONEY', 'description': 'A collection of poetry about love, loss, trauma and healing.', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449474256', 'primary_isbn10': '144947425X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-02', 'published_date': '2017-12-17', 'rank': 4, 'rank_last_week': 3, 'weeks_on_list': 16, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Stephen-King-ebook/dp/B018ER7K5I?tag=NYTBS-20', 'isbns': [{'isbn10': '1501141236', 'isbn13': '9781501141232'}, {'isbn10': '1501142976', 'isbn13': '9781501142970'}, {'isbn10': '1501156683', 'isbn13': '9781501156687'}, {'isbn10': '1501182099', 'isbn13': '9781501182099'}, {'isbn10': '1501175467', 'isbn13': '9781501175466'}], 'book_details': [{'title': 'IT', 'description': 'The fears of seven teenagers are rekindled in their adult lives by the terrifying title character. Originally published in 1986.', 'contributor': 'by Stephen King', 'author': 'Stephen King', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Scribner', 'primary_isbn13': '9781501175466', 'primary_isbn10': '1501175467'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sund ...
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 10, 'last_modified': '2017-12-15T14:38:02-05:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-09', 'published_date': '2017-12-24', 'rank': 1, 'rank_last_week': 2, 'weeks_on_list': 10, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Sun-Her-Flowers-Rupi-Kaur/dp/1449486797?tag=NYTBS-20', 'isbns': [{'isbn10': '1449486797', 'isbn13': '9781449486792'}, {'isbn10': '1449488897', 'isbn13': '9781449488895'}], 'book_details': [{'title': 'THE SUN AND HER FLOWERS', 'description': 'A second collection of poetry from the author of "Milk and Honey."', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449486792', 'primary_isbn10': '1449486797'}], 'reviews': [{'book_review_link': 'https://www.nytimes.com/2017/12/15/books/review/rupi-kaur-instapoets.html', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-09', 'published_date': '2017-12-24', 'rank': 2, 'rank_last_week': 1, 'weeks_on_list': 2, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Darker-Fifty-Shades-Told-Christian-ebook/dp/B07693HRS9?tag=NYTBS-20', 'isbns': [{'isbn10': '0385543913', 'isbn13': '9780385543910'}, {'isbn10': '0385543980', 'isbn13': '9780385543989'}], 'book_details': [{'title': 'DARKER', 'description': "Christian Grey's tormented and difficult pursuit of Anastasia Steele is told from his perspective.", 'contributor': 'by E.L. James', 'author': 'EL James', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Vintage', 'primary_isbn13': '9780385543910', 'primary_isbn10': '0385543913'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-09', 'published_date': '2017-12-24', 'rank': 3, 'rank_last_week': 3, 'weeks_on_list': 87, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Milk-Honey-Rupi-Kaur/dp/144947425X?tag=NYTBS-20', 'isbns': [{'isbn10': '144947425X', 'isbn13': '9781449474256'}], 'book_details': [{'title': 'MILK AND HONEY', 'description': 'A collection of poetry about love, loss, trauma and healing.', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449474256', 'primary_isbn10': '144947425X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-09', 'published_date': '2017-12-24', 'rank': 4, 'rank_last_week': 4, 'weeks_on_list': 17, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Stephen-King-ebook/dp/B018ER7K5I?tag=NYTBS-20', 'isbns': [{'isbn10': '1501141236', 'isbn13': '9781501141232'}, {'isbn10': '1501142976', 'isbn13': '9781501142970'}, {'isbn10': '1501156683', 'isbn13': '9781501156687'}, {'isbn10': '1501182099', 'isbn13': '9781501182099'}, {'isbn10': '1501175467', 'isbn13': '9781501175466'}], 'book_details': [{'title': 'IT', 'description': 'The fears of seven teenagers are rekindled in their adult lives by the terrifying title character. Originally published in 1986.', 'contributor': 'by Stephen King', 'author': 'Stephen King', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Scribner', 'primary_isbn13': '9781501175466', 'primary_isbn10': '1501175467'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sun ...
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 10, 'last_modified': '2017-12-22T14:38:02-05:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-16', 'published_date': '2017-12-31', 'rank': 1, 'rank_last_week': 1, 'weeks_on_list': 11, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Sun-Her-Flowers-Rupi-Kaur/dp/1449486797?tag=NYTBS-20', 'isbns': [{'isbn10': '1449486797', 'isbn13': '9781449486792'}, {'isbn10': '1449488897', 'isbn13': '9781449488895'}], 'book_details': [{'title': 'THE SUN AND HER FLOWERS', 'description': 'A second collection of poetry from the author of "Milk and Honey."', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449486792', 'primary_isbn10': '1449486797'}], 'reviews': [{'book_review_link': 'https://www.nytimes.com/2017/12/15/books/review/rupi-kaur-instapoets.html', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-16', 'published_date': '2017-12-31', 'rank': 2, 'rank_last_week': 3, 'weeks_on_list': 88, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Milk-Honey-Rupi-Kaur/dp/144947425X?tag=NYTBS-20', 'isbns': [{'isbn10': '144947425X', 'isbn13': '9781449474256'}], 'book_details': [{'title': 'MILK AND HONEY', 'description': 'A collection of poetry about love, loss, trauma and healing.', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449474256', 'primary_isbn10': '144947425X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-16', 'published_date': '2017-12-31', 'rank': 3, 'rank_last_week': 2, 'weeks_on_list': 3, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Darker-Fifty-Shades-Told-Christian-ebook/dp/B07693HRS9?tag=NYTBS-20', 'isbns': [{'isbn10': '0385543913', 'isbn13': '9780385543910'}, {'isbn10': '0385543980', 'isbn13': '9780385543989'}], 'book_details': [{'title': 'DARKER', 'description': "Christian Grey's tormented and difficult pursuit of Anastasia Steele is told from his perspective.", 'contributor': 'by E.L. James', 'author': 'EL James', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Vintage', 'primary_isbn13': '9780385543910', 'primary_isbn10': '0385543913'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-16', 'published_date': '2017-12-31', 'rank': 4, 'rank_last_week': 5, 'weeks_on_list': 37, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Ready-Player-One-Ernest-Cline/dp/030788743X?tag=NYTBS-20', 'isbns': [{'isbn10': '030788743X', 'isbn13': '9780307887436'}, {'isbn10': '0307887448', 'isbn13': '9780307887443'}, {'isbn10': '0307887456', 'isbn13': '9780307887450'}, {'isbn10': '1524755613', 'isbn13': '9781524755614'}, {'isbn10': '1524763284', 'isbn13': '9781524763282'}, {'isbn10': '0606264124', 'isbn13': '9780606264129'}, {'isbn10': '0804190135', 'isbn13': '9780804190138'}, {'isbn10': '0804190143', 'isbn13': '9780804190145'}, {'isbn10': '0307913147', 'isbn13': '9780307913142'}], 'book_details': [{'title': 'READY PLAYER ONE', 'description': 'In 2044, the key to a vast fortune is hidden in a virtual-reality world. 15 hours, 46 minutes unabridged. Read by Wil Wheaton.', 'contributor': 'by Ernest Cline', 'autho ...
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 10, 'last_modified': '2017-12-29T14:38:01-05:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-23', 'published_date': '2018-01-07', 'rank': 1, 'rank_last_week': 1, 'weeks_on_list': 12, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Sun-Her-Flowers-Rupi-Kaur/dp/1449486797?tag=NYTBS-20', 'isbns': [{'isbn10': '1449486797', 'isbn13': '9781449486792'}, {'isbn10': '1449488897', 'isbn13': '9781449488895'}], 'book_details': [{'title': 'THE SUN AND HER FLOWERS', 'description': 'A second collection of poetry from the author of "Milk and Honey."', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449486792', 'primary_isbn10': '1449486797'}], 'reviews': [{'book_review_link': 'https://www.nytimes.com/2017/12/15/books/review/rupi-kaur-instapoets.html', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-23', 'published_date': '2018-01-07', 'rank': 2, 'rank_last_week': 2, 'weeks_on_list': 89, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Milk-Honey-Rupi-Kaur/dp/144947425X?tag=NYTBS-20', 'isbns': [{'isbn10': '144947425X', 'isbn13': '9781449474256'}], 'book_details': [{'title': 'MILK AND HONEY', 'description': 'A collection of poetry about love, loss, trauma and healing.', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449474256', 'primary_isbn10': '144947425X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-23', 'published_date': '2018-01-07', 'rank': 3, 'rank_last_week': 3, 'weeks_on_list': 4, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Darker-Fifty-Shades-Told-Christian-ebook/dp/B07693HRS9?tag=NYTBS-20', 'isbns': [{'isbn10': '0385543913', 'isbn13': '9780385543910'}, {'isbn10': '0385543980', 'isbn13': '9780385543989'}], 'book_details': [{'title': 'DARKER', 'description': "Christian Grey's tormented and difficult pursuit of Anastasia Steele is told from his perspective.", 'contributor': 'by E.L. James', 'author': 'EL James', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Vintage', 'primary_isbn13': '9780385543910', 'primary_isbn10': '0385543913'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-23', 'published_date': '2018-01-07', 'rank': 4, 'rank_last_week': 4, 'weeks_on_list': 38, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Ready-Player-One-Ernest-Cline/dp/030788743X?tag=NYTBS-20', 'isbns': [{'isbn10': '030788743X', 'isbn13': '9780307887436'}, {'isbn10': '0307887448', 'isbn13': '9780307887443'}, {'isbn10': '0307887456', 'isbn13': '9780307887450'}, {'isbn10': '1524755613', 'isbn13': '9781524755614'}, {'isbn10': '1524763284', 'isbn13': '9781524763282'}, {'isbn10': '0606264124', 'isbn13': '9780606264129'}, {'isbn10': '0804190135', 'isbn13': '9780804190138'}, {'isbn10': '0804190143', 'isbn13': '9780804190145'}, {'isbn10': '0307913147', 'isbn13': '9780307913142'}], 'book_details': [{'title': 'READY PLAYER ONE', 'description': 'In 2044, the key to a vast fortune is hidden in a virtual-reality world. 15 hours, 46 minutes unabridged. Read by Wil Wheaton.', 'contributor': 'by Ernest Cline', 'autho ...
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 10, 'last_modified': '2018-01-05T14:38:03-05:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-30', 'published_date': '2018-01-14', 'rank': 1, 'rank_last_week': 1, 'weeks_on_list': 13, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Sun-Her-Flowers-Rupi-Kaur/dp/1449486797?tag=NYTBS-20', 'isbns': [{'isbn10': '1449486797', 'isbn13': '9781449486792'}, {'isbn10': '1449488897', 'isbn13': '9781449488895'}], 'book_details': [{'title': 'THE SUN AND HER FLOWERS', 'description': 'A second collection of poetry from the author of "Milk and Honey."', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449486792', 'primary_isbn10': '1449486797'}], 'reviews': [{'book_review_link': 'https://www.nytimes.com/2017/12/15/books/review/rupi-kaur-instapoets.html', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-30', 'published_date': '2018-01-14', 'rank': 2, 'rank_last_week': 2, 'weeks_on_list': 90, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Milk-Honey-Rupi-Kaur/dp/144947425X?tag=NYTBS-20', 'isbns': [{'isbn10': '144947425X', 'isbn13': '9781449474256'}], 'book_details': [{'title': 'MILK AND HONEY', 'description': 'A collection of poetry about love, loss, trauma and healing.', 'contributor': 'by Rupi Kaur', 'author': 'Rupi Kaur', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Andrews McMeel', 'primary_isbn13': '9781449474256', 'primary_isbn10': '144947425X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-30', 'published_date': '2018-01-14', 'rank': 3, 'rank_last_week': 3, 'weeks_on_list': 5, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/Darker-Fifty-Shades-Told-Christian-ebook/dp/B07693HRS9?tag=NYTBS-20', 'isbns': [{'isbn10': '0385543913', 'isbn13': '9780385543910'}, {'isbn10': '0385543980', 'isbn13': '9780385543989'}], 'book_details': [{'title': 'DARKER', 'description': "Christian Grey's tormented and difficult pursuit of Anastasia Steele is told from his perspective.", 'contributor': 'by E.L. James', 'author': 'EL James', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Vintage', 'primary_isbn13': '9780385543910', 'primary_isbn10': '0385543913'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2017-12-30', 'published_date': '2018-01-14', 'rank': 4, 'rank_last_week': 4, 'weeks_on_list': 39, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Ready-Player-One-Ernest-Cline/dp/030788743X?tag=NYTBS-20', 'isbns': [{'isbn10': '030788743X', 'isbn13': '9780307887436'}, {'isbn10': '0307887448', 'isbn13': '9780307887443'}, {'isbn10': '0307887456', 'isbn13': '9780307887450'}, {'isbn10': '1524755613', 'isbn13': '9781524755614'}, {'isbn10': '1524763284', 'isbn13': '9781524763282'}, {'isbn10': '0606264124', 'isbn13': '9780606264129'}, {'isbn10': '0804190135', 'isbn13': '9780804190138'}, {'isbn10': '0804190143', 'isbn13': '9780804190145'}, {'isbn10': '0307913147', 'isbn13': '9780307913142'}], 'book_details': [{'title': 'READY PLAYER ONE', 'description': 'In 2044, the key to a vast fortune is hidden in a virtual-reality world. 15 hours, 46 minutes unabridged. Read by Wil Wheaton.', 'contributor': 'by Ernest Cline', 'autho ...
