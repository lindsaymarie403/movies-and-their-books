# %%
# import libraries
import pandas as pd

# %%
# get all tables
tables10 = pd.read_html("https://www.boxofficemojo.com/yearly/chart/?yr=2010&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm")

# %%
movies10 = tables10[3]

# %%
movies10 = movies10[5:]
movies10 = movies10[:100]
movies10 = movies10.iloc[:,0:4]
movies10
# Out:
#        0                                                  1        2  \
# 5      1                                        Toy Story 3       BV
# 6      2                         Alice in Wonderland (2010)       BV
# 7      3                                         Iron Man 2     Par.
# 8      4                         The Twilight Saga: Eclipse     Sum.
# 9      5        Harry Potter and the Deathly Hallows Part 1       WB
# 10     6                                          Inception       WB
# 11     7                                      Despicable Me     Uni.
# 12     8                                Shrek Forever After     P/DW
# 13     9                           How to Train Your Dragon     P/DW
# 14    10                                            Tangled       BV
# 15    11                                     The Karate Kid     Sony
# 16    12                                        Tron Legacy       BV
# 17    13                                          True Grit     Par.
# ...
