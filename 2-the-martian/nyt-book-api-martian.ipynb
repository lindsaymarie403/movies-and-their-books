# %% [markdown]
# Tracking the histories of books-turned-movies on the NYT Best Sellers List. What sort of relationship exists between the book's rank and the date its movie was released?
#
# Note: The list combines all books in a series into one listing under Children's Series. This is relevant for the following books/movies I'm examining: The Twilight Saga: Eclipse, Harry Potter and the Deathly Hallows Part 1, Harry Potter and the Deathly Hallows Part 2, The Twilight Saga: Breaking Dawn Part 1, The Hunger Games, The Twilight Saga Breaking Dawn Part 2, The Hunger Games: Catching Fire, The Hunger Games: Mockingjay - Part 1 and The Hunger Games: Mockingjay - Part 2.

# %%
import requests
import pandas as pd
import json

# %%
data = pd.read_csv('input/trade-fiction-martian16.csv', encoding='utf8')

dates = data['Date'].tolist()

print(dates)
# Out:
# ['2016-04-24']

# %%
for date in dates:
    # Set up the parameters we want to pass to the API.
    parameters = {"api-key": "e67cf24bfe5e41628e9b424f1e479900", "list": "trade-fiction-paperback", "published-date": date}
    
    # Make a get request with the parameters.
    response = requests.get("https://api.nytimes.com/svc/books/v3/lists.json", params=parameters)
    
    response = response.json()
    
    print(response)
    
    with open('output/data16.json', 'a') as outfile:
        json.dump(response, outfile, indent=4, sort_keys=True)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company.  All Rights Reserved.', 'num_results': 15, 'last_modified': '2017-03-21T13:38:01-04:00', 'results': [{'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2016-04-09', 'published_date': '2016-04-24', 'rank': 1, 'rank_last_week': 0, 'weeks_on_list': 1, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/One-You-A-Crossfire-Novel/dp/1250109302?tag=NYTBS-20', 'isbns': [{'isbn10': '1250109302', 'isbn13': '9781250109309'}, {'isbn10': '1250109310', 'isbn13': '9781250109316'}], 'book_details': [{'title': 'ONE WITH YOU', 'description': 'Fighting for the love to which they have committed could set Gideon and Eva free, or break them apart; the finale of the Crossfire series.', 'contributor': 'by Sylvia Day', 'author': 'Sylvia Day', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': "St. Martin's Griffin", 'primary_isbn13': '9781250109309', 'primary_isbn10': '1250109302'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2016-04-09', 'published_date': '2016-04-24', 'rank': 2, 'rank_last_week': 0, 'weeks_on_list': 70, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Me-Before-You-A-Novel/dp/0143124544?tag=NYTBS-20', 'isbns': [{'isbn10': '0670026603', 'isbn13': '9780670026609'}, {'isbn10': '0143124544', 'isbn13': '9780143124542'}, {'isbn10': '1594137390', 'isbn13': '9781594137396'}, {'isbn10': '0143109464', 'isbn13': '9780143109464'}, {'isbn10': '0143130153', 'isbn13': '9780143130154'}], 'book_details': [{'title': 'ME BEFORE YOU', 'description': 'A young woman who has barely been farther afield than her English village finds herself while caring for a wealthy, embittered quadriplegic.', 'contributor': 'by Jojo Moyes', 'author': 'Jojo Moyes', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Penguin', 'primary_isbn13': '9780143124542', 'primary_isbn10': '0143124544'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': 'https://www.nytimes.com/2013/01/06/books/review/me-before-you-by-jojo-moyes.html', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2016-04-09', 'published_date': '2016-04-24', 'rank': 3, 'rank_last_week': 0, 'weeks_on_list': 1, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/The-Murder-House-James-Patterson-ebook/dp/B00QQQL8JY?tag=NYTBS-20', 'isbns': [{'isbn10': '0316410985', 'isbn13': '9780316410984'}, {'isbn10': '0316337978', 'isbn13': '9780316337977'}, {'isbn10': '145558990X', 'isbn13': '9781455589906'}, {'isbn10': '1455589918', 'isbn13': '9781455589913'}], 'book_details': [{'title': 'THE MURDER HOUSE', 'description': 'When bodies are found at a Hamptons estate where a series of grisly murders once occurred, a local detective and former New York City cop investigates.', 'contributor': 'by James Patterson and David Ellis', 'author': 'James Patterson and David Ellis', 'contributor_note': '', 'price': 0, 'age_group': '', 'publisher': 'Grand Central', 'primary_isbn13': '9781455589906', 'primary_isbn10': '145558990X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Trade Fiction Paperback', 'display_name': 'Paperback Trade Fiction', 'bestsellers_date': '2016-04-09', 'published_date': '2016-04-24', 'rank': 4, 'rank_last_week': 0, 'weeks_on_list': 1, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'http://www.amazon.com/Luckiest-Girl-Alive-A-Novel-ebook/dp/B00LD1OITO?tag=NYTBS-20', 'isbns': [{'isbn10': '1476789630', 'isbn13': '9781476789637'}, {'isbn10': '1476789657', 'isbn13': '9781476789651'}, {'isbn10': '1476789649', ...
